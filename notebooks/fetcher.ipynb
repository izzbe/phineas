# %%
import httpx
import json

# %%
url = "https://wrds-api.wharton.upenn.edu/data/comp.fundq/"
auth = {"Authorization": "Token 158d18600b24ddece0c9532fc57b20c9c16f3a5b"}

# %%
response = httpx.get(url, headers=auth, params={"limit": 10}, timeout=60)

# %%
len(response.json()['results'])
# Out:
# 100000

# %%
with open("sample/fundamental.json", mode="w") as f:
    json.dump(response.json(), f, indent=4)

# %%
print(response.json()["previous"])
# Out:
# None

# %%
from common.mapping import *

# %%
map = get_mapping("header")

# %%
", ".join(map.values())
# Out:
# 'permno, permco, cusip, issuer_name, security_name, ticker, info_valid_start, info_valid_end, security_start, security_end, security_type, security_subtype, share_class, primary_exchange, trading_status, SIC_code, naics, us_incorporation'

# %%
import json
with open("sample/headers.json", mode="r") as f:
    results = json.load(f)

# %%
from common.mapping import *
mapping=get_mapping("header")
tups = get_tuples(results["results"], "header", mapping)

# %%
tups
# Out:
# [(10000,
#   7952,
#   '68391610',
#   'OPTIMUM MANUFACTURING INC',
#   'OPTIMUM MANUFACTURING INC; COM A; CONS',
#   'OMFGA',
#   datetime.date(1987, 3, 10),
#   datetime.date(1987, 6, 11),
#   datetime.date(1986, 1, 7),
#   datetime.date(1987, 6, 11),
#   'EQTY',
#   'COM',
#   'A',
#   'Q',
#   'A',
#   3990,
#   '0',
#   'Y'),
#  (10001,
#   7953,
#   '36720410',
#   'GAS NATURAL INC',
#   'GAS NATURAL INC; COM NONE; CONS',
#   'EGAS',
#   datetime.date(2010, 7, 9),
#   datetime.date(2017, 8, 3),
#   datetime.date(1986, 1, 9),
#   datetime.date(2017, 8, 3),
#   'EQTY',
#   'COM',
#   None,
#   'A',
#   'A',
#   4925,
#   '221210',
#   'Y'),
#  (10002,
#   7954,
#   '05978R10',
#   'BANCTRUST FINANCIAL GROUP INC',
#   'BANCTRUST FINANCIAL GROUP INC; COM NONE; CONS',
#   'BTFG',
#   datetime.date(2008, 6, 27),
#   datetime.date(2013, 2, 15),
#   datetime.date(1986, 1, 10),
#   datetime.date(2013, 2, 15),
#   'EQTY',
#   'COM',
#   None,
#   'Q',
#   'A',
#   6020,
#   '551111',
#   'Y'),
#  (10003,
#   7957,
#   '39031810',
#   'GREAT COUNTRY BK ASONIA CT',
#   'GREAT COUNTRY BK ASONIA CT; COM NONE; CONS',
#   'GCBK',
#   datetime.date(1987, 4, 1),
#   datetime.date(1995, 12, 15),
#   datetime.date(1986, 1, 14),
#   datetime.date(1995, 12, 15),
#   'EQTY',
#   'COM',
#   None,
#   'Q',
#   'A',
#   6020,
#   '0',
#   'Y'),
#  (10004,
#   7960,
#   '18906310',
#   'CLOSE OUTS PLUS INC',
#   'CLOSE OUTS PLUS INC; COM NONE; CONS',
#   'CLSO',
#   datetime.date(1986, 1, 15),
#   datetime.date(1986, 1, 17),
#   datetime.date(1986, 1, 15),
#   datetime.date(1986, 1, 17),
#   'EQTY',
#   'COM',
#   None,
#   'Q',
#   'A',
#   5330,
#   '0',
#   'Y'),
#  (10005,
#   7961,
#   '95815510',
#   'WESTERN ENERGY RESOURCES INC',
#   'WESTERN ENERGY RESOURCES INC; COM NONE; CONS',
#   'WERC',
#   datetime.date(1986, 1, 15),
#   datetime.date(1991, 7, 11),
#   datetime.date(1986, 1, 15),
#   datetime.date(1991, 7, 11),
#   'EQTY',
#   'COM',
#   None,
#   'Q',
#   'A',
#   1310,
#   '0',
#   'Y'),
#  (10006,
#   22156,
#   '00080010',
#   'A C F INDUSTRIES INC',
#   'A C F INDUSTRIES INC; COM NONE; CONS',
#   'ACF',
#   datetime.date(1968, 1, 2),
#   datetime.date(1984, 6, 28),
#   datetime.date(1925, 12, 31),
#   datetime.date(1984, 6, 28),
#   'EQTY',
#   'COM',
#   None,
#   'N',
#   'A',
#   3743,
#   '0',
#   'Y'),
#  (10007,
#   7963,
#   '81949130',
#   'SHAREDATA INC',
#   'SHAREDATA INC; COM NONE; CONS',
#   'SHRD',
#   datetime.date(1990, 7, 13),
#   datetime.date(1990, 10, 16),
#   datetime.date(1986, 1, 16),
#   datetime.date(1990, 10, 16),
#   'EQTY',
#   'COM',
#   None,
#   'Q',
#   'A',
#   7370,
#   '0',
#   'Y'),
#  (10008,
#   7964,
#   '36547310',
#   'GARDENAMERICA CORP',
#   'GARDENAMERICA CORP; COM NONE; CONS',
#   'GACO',
#   datetime.date(1986, 9, 16),
#   datetime.date(1988, 11, 21),
#   datetime.date(1986, 1, 16),
#   datetime.date(1988, 11, 21),
#   'EQTY',
#   'COM',
#   None,
#   'Q',
#   'A',
#   3430,
#   '0',
#   'Y'),
#  (10009,
#   7965,
#   '46334710',
#   'IROQUOIS BANCORP INC',
#   'IROQUOIS BANCORP INC; COM NONE; CONS',
#   'IROQ',
#   datetime.date(1999, 7, 1),
#   datetime.date(2000, 11, 3),
#   datetime.date(1986, 1, 17),
#   datetime.date(2000, 11, 3),
#   'EQTY',
#   'COM',
#   None,
#   'Q',
#   'A',
#   6030,
#   '0',
#   'Y')]

# %%
from common.db import dsn

# %%
dsn
# Out:
# 'postgresql://hist:hist@localhost:5432/hist'

# %%
from dotenv import load_dotenv
load_dotenv("../.env")
# Out:
# True

# %%
from common.universe import UNIVERSE
UNIVERSE

# %%
print(UNIVERSE)
# Out:
# None
